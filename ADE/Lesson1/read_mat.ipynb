# %%
from scipy.io import loadmat, whosmat

# Just see what variables are inside:
info = whosmat('../mat/nfet_01v8_lvt.mat')
print(info)
# -> [('var1', (100, 1), 'double'), ('var2', (1, 1), 'cell'), ...]

# Actually load them:
data = loadmat('../mat/nfet_01v8_lvt.mat')
print(data.keys())  # shows variable names
print(data['nfet_01v8_lvt']) # access a variable (numpy array)
# Out:
# [('nfet_01v8_lvt', (1, 1), 'struct')]
# dict_keys(['__header__', '__version__', '__globals__', 'nfet_01v8_lvt'])
# [[(array(['SkyWater, 130nm CMOS, BSIM4'], dtype='<U27'), array(['NOM'], dtype='<U3'), array([[300.]]), array([[0.   , 0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  ,
#           0.225, 0.25 , 0.275, 0.3  , 0.325, 0.35 , 0.375, 0.4  , 0.425,
#           0.45 , 0.475, 0.5  , 0.525, 0.55 , 0.575, 0.6  , 0.625, 0.65 ,
#           0.675, 0.7  , 0.725, 0.75 , 0.775, 0.8  , 0.825, 0.85 , 0.875,
#           0.9  , 0.925, 0.95 , 0.975, 1.   , 1.025, 1.05 , 1.075, 1.1  ,
#           1.125, 1.15 , 1.175, 1.2  , 1.225, 1.25 , 1.275, 1.3  , 1.325,
#           1.35 , 1.375, 1.4  , 1.425, 1.45 , 1.475, 1.5  , 1.525, 1.55 ,
#           1.575, 1.6  , 1.625, 1.65 , 1.675, 1.7  , 1.725, 1.75 , 1.775,
#           1.8  ]]), array([[0.   , 0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  ,
#           0.225, 0.25 , 0.275, 0.3  , 0.325, 0.35 , 0.375, 0.4  , 0.425,
# ...
